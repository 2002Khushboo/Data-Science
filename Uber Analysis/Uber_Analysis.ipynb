# %% [markdown]
# #UBER Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import time,datetime

# %%
df=pd.read_csv('My Uber Drives - 2016.csv')

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
#df.columns=df.columns.replace('*',' ')
df.columns=[i.replace('*','') for i in df.columns]
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
#df=np.delete(df,-1,axis=0)
df=df.drop(1155,axis=0)
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
df.isnull().sum()
# Out:
# START_DATE      0
# END_DATE        0
# CATEGORY        0
# START           0
# STOP            0
# MILES           0
# PURPOSE       502
# dtype: int64

# %%
#df["PURPOSE"].isna().mean()*100
df.isnull().sum() * 100 / len(df)
# Out:
# START_DATE     0.000000
# END_DATE       0.000000
# CATEGORY       0.000000
# START          0.000000
# STOP           0.000000
# MILES          0.000000
# PURPOSE       43.463203
# dtype: float64

# %%
df.columns['PURPOSE'].fillna(method='ffill',inplace='True')
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-50fec870bd8b> in <module>()
# ----> 1 df.columns['PURPOSE'].fillna(method='ffill',inplace='True')
#       2 df.isnull().sum()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4602         if is_scalar(key):
#    4603             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4604             return getitem(key)
#    4605
#    4606         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
df.groupby(['START']).value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-a9b1019de3e7> in <module>()
# ----> 1 df.groupby(['START']).value_counts()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     910
#     911         raise AttributeError(
# --> 912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#     914
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'

# %%
df['MILES'].describe()
# Out:
# count    1155.000000
# mean       10.566840
# std        21.579106
# min         0.500000
# 25%         2.900000
# 50%         6.000000
# 75%        10.400000
# max       310.300000
# Name: MILES, dtype: float64

# %%
df['CATEGORY'].value_counts()
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY, dtype: int64

# %%
df['MILES'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1150    False
# 1151    False
# 1152    False
# 1153    False
# 1154    False
# Name: MILES, Length: 1155, dtype: bool

# %%
df.groupby(['PURPOSE'])['MILES'].mean()
# Out:
# PURPOSE
# Airport/Travel       5.500000
# Between Offices     10.944444
# Charity ($)         15.100000
# Commute            180.200000
# Customer Visit      20.688119
# Errand/Supplies      3.968750
# Meal/Entertain       5.698125
# Meeting             15.247594
# Moving               4.550000
# Temporary Site      10.474000
# Name: MILES, dtype: float64

# %%
df.groupby(['PURPOSE']).agg({'MILES':['mean','max','min']})
# Out:
#                       MILES
#                        mean    max    min
# PURPOSE
# Airport/Travel     5.500000    7.6    4.1
# Between Offices   10.944444   39.2    1.9
# Charity ($)       15.100000   15.1   15.1
# Commute          180.200000  180.2  180.2
# Customer Visit    20.688119  310.3    0.8
# Errand/Supplies    3.968750   22.3    0.5
# Meal/Entertain     5.698125   36.5    0.6
# Meeting           15.247594  201.0    0.7
# Moving             4.550000    6.1    3.3
# Temporary Site    10.474000   48.2    1.8

# %%
rt=(df['START']==df['STOP'])
rt.value_counts()
# Out:
# False    867
# True     288
# dtype: int64

# %%
df[rt]
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Kar?chi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
df['minutes']=pd.DatetimeIndex(df['END_DATE']-df['START_DATE']).minutes
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ...

# %%
df['months']=pd.DatetimeIndex(df['START_DATE']).month
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE  months
# 0          Fort Pierce    5.1   Meal/Entertain       1
# ...

# %%
dic={1:'jan',2:'feb',3:'mar',4:'apr',5:'may',6:'jun',7:'jul',8:'aug',9:'sep',10:'oct',11:'nov',12:'dec'}
df['months']=df['months'].map(dic)
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE months
# 0          Fort Pierce    5.1   Meal/Entertain    jan
# ...

# %%
df[rt].value_counts()
# Out:
# START_DATE        END_DATE          CATEGORY  START             STOP              MILES  PURPOSE          months
# 1/1/2016 21:11    1/1/2016 21:17    Business  Fort Pierce       Fort Pierce       5.1    Meal/Entertain   jan       1
# 12/7/2016 19:53   12/7/2016 20:13   Business  Cary              Cary              7.0    Customer Visit   dec       1
# 12/30/2016 23:06  12/30/2016 23:10  Business  Kar?chi           Kar?chi           0.8    Customer Visit   dec       1
# 12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location  Unknown Location  16.2   Meeting          dec       1
# 12/31/2016 1:07   12/31/2016 1:14   Business  Kar?chi           Kar?chi           0.7    Meeting          dec       1
#                                                                                                                    ..
# 12/20/2016 10:30  12/20/2016 10:48  Business  Rawalpindi        Rawalpindi        3.3    Errand/Supplies  dec       1
# ...

# %%
df['round_trip']=rt
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE months  round_trip
# 0          Fort Pierce    5.1   Meal/Entertain    jan        True
# ...

# %%
df.groupby(['months','round_trip'])['round_trip'].count()
# Out:
# months  round_trip
# apr     False          49
#         True            5
# aug     False          86
#         True           47
# dec     False          63
#         True           83
# feb     False          86
#         True           29
# jan     False          44
#         True           17
# jul     False         101
#         True           11
# jun     False          97
#         True           11
# mar     False          99
#         True           14
# may     False          49
# nov     False          96
#         True           26
# oct     False          82
#         True           24
# sep     False          15
#         True           21
# Name: round_trip, dtype: int64

# %%
sns.lineplot('minutes','MILES',*,markersize=15,linestyle='_',linewidth=6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-ddb776f8f591> in <module>()
# ----> 1 sns.lineplot('minutes','MILES',markersize=15,linestyle='_',linewidth=6)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     693         data=data, variables=variables,
#     694         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
# ...

# %%
df.groupby(['PURPOSE','CATEGORY'])['CATEGORY'].count()
# Out:
# PURPOSE          CATEGORY
# Airport/Travel   Business      3
# Between Offices  Business     18
# Charity ($)      Personal      1
# Commute          Personal      1
# Customer Visit   Business    101
# Errand/Supplies  Business    128
# Meal/Entertain   Business    160
# Meeting          Business    187
# Moving           Personal      4
# Temporary Site   Business     50
# Name: CATEGORY, dtype: int64
